# %% [markdown]
# # Project 3 #

# %% [markdown]
# ## Linear Regression ##

# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("salary.csv")
print(df.head(10))
print("\n")
print(df.tail(10))
# Out:
#    Years_of_Experience  Salary
# 0                 11.7  161448
# 1                 10.4  112447
# 2                  0.6   31510
# 3                  6.6   85290
# 4                  7.3  116412
# 5                 11.7  181329
# 6                  2.5   58171
# 7                  8.7  109872
# 8                  6.5   92875
# 9                  1.8   48841
#
#
#     Years_of_Experience  Salary
# 25                  7.1  102845
# 26                  6.8   98571
# 27                 10.8  160471
# 28                  4.9   64309
# 29                 13.7  181847
# 30                 11.0  136973
# 31                  6.1   80513
# 32                  3.7   56697
# 33                  2.2   44034
# 34                  6.7   93727

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Years_of_Experience  35 non-null     float64
#  1   Salary               35 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 692.0 bytes
# None

# %%
print(df.isnull().sum())
print("\n")
print(df.describe())
# Out:
# Years_of_Experience    0
# Salary                 0
# dtype: int64
#
#
#        Years_of_Experience         Salary
# count            35.000000      35.000000
# mean              7.571429  108796.714286
# std               3.757469   46536.084642
# min               0.600000   31510.000000
# 25%               5.050000   74339.000000
# 50%               7.200000  102845.000000
# 75%              10.850000  144742.000000
# max              13.700000  219320.000000

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Years_of_Experience"], df["Salary"],color="red")

plt.xlabel("Years of Experience")
plt.ylabel("Salary")

plt.title("Experience vs Salary")

plt.show()

# %% [markdown]
# ### X = independent , Y = dependent on X

# %%
X = df[["Years_of_Experience"]]
y = df["Salary"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,   # 20%
    random_state=42
)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [11996.57617538]
# 18263.46089691829

# %% [markdown]
# ## Evaluation Matrix ##

# %%
mae = mean_absolute_error(y_test, y_pred)
print(mae)

print("\n")

mse = mean_squared_error(y_test, y_pred)
print(mse)

print("\n")

rmse = np.sqrt(mse)
print(rmse)
print("\n")

r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 8535.723056209328
#
#
# 166432516.92316723
#
#
# 12900.87271943907
#
#
# 0.913281985932304

# %% [markdown]
# ### Regression line graph ###

# %%
plt.figure(figsize=(8,5))

plt.scatter(X, y,color="red")

plt.plot(X, model.predict(X))

plt.xlabel("Years of Experience")
plt.ylabel("Salary")

plt.title("Linear Regression Fit")

plt.show()

# %%
accuracy = r2
print("Accuracy is : ",accuracy)
# Out:
# Accuracy is :  0.913281985932304

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.bar(
    df["Years_of_Experience"],
    df["Salary"]
)

plt.xlabel("Years of Experience")
plt.ylabel("Salary")

plt.title("Bar Graph of Experience vs Salary")

plt.show()

# %%
plt.figure(figsize=(6,5))

plt.boxplot(df["Salary"])

plt.title("Box Plot of Salary")

plt.ylabel("Salary")

plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(6,4))

sns.heatmap(
    df.corr(),
    annot=True
)

plt.title("Correlation Heatmap")

plt.show()
